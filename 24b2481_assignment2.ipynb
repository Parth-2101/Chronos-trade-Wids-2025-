# %%
import pandas as pd
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# # **Data Collection**

# %%
# Microsoft data for the last five years
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=5*365)
df=yf.download("MSFT",start=start_date,end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # **Preprocessing the Data**

# %%
print(df.head())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-01-16  158.939163  159.006124  156.892285  157.198368  23865400
# 2020-01-17  159.828720  160.182615  158.231377  160.134788  34371700
# 2020-01-21  159.254837  160.871300  159.187876  159.426997  29517200
# 2020-01-22  158.489655  160.201772  158.470521  160.115677  24138800
# 2020-01-23  159.465271  159.541792  158.078370  158.958335  19680800

# %% [markdown]
# Checking for any missing values

# %%
print(df.isnull().any().any())
# Out:
# False

# %% [markdown]
# Checking for data types in the coloumns

# %%
print(df.dtypes)
# Out:
# Price   Ticker
# Close   MSFT      float64
# High    MSFT      float64
# Low     MSFT      float64
# Open    MSFT      float64
# Volume  MSFT        int64
# dtype: object

# %% [markdown]
# Convert the date column to a datetime object and set it as the index.

# %% [markdown]
# I think this is already the case for the data downloaded, I will jsut go ahead and print the index.

# %%
print(df.index)
# Out:
# DatetimeIndex(['2020-01-16', '2020-01-17', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30',
#                ...
#                '2024-12-30', '2024-12-31', '2025-01-02', '2025-01-03',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-10',
#                '2025-01-13', '2025-01-14'],
#               dtype='datetime64[ns]', name='Date', length=1256, freq=None)

# %% [markdown]
# Filter and retain only the closing price or a similar indicator for analysis.

# %%
df.drop(columns=['Open', 'High','Volume','Low'], inplace=True)

# %%
df.head()
# Out:
# Price            Close
# Ticker            MSFT
# Date
# 2020-01-16  158.939163
# 2020-01-17  159.828720
# 2020-01-21  159.254837
# 2020-01-22  158.489655
# 2020-01-23  159.465271

# %% [markdown]
# Normalize the data between 0 and 1 for LSTM implementation.

# %% [markdown]
# I am going to duplicate this dataframe and keep the original one.

# %%
dfnew=df.copy()

# %% [markdown]
# using the max-min scaling, from sklearn

# %%
scaler = MinMaxScaler()
dfnew['Close Normalized'] = scaler.fit_transform(dfnew[['Close']])
dfnew.drop(columns=['Close'],inplace=True)

# %% [markdown]
# Split the data into training (80%) and testing (20%) sets.

# %%
index_value=int(0.8*(int(df.shape[0])))
training_df=df[:index_value]
testing_df=df[index_value:]
training_dfnew=dfnew[:index_value]
testing_dfnew=dfnew[index_value:]

# %% [markdown]
# # **ARIMA Model**

# %% [markdown]
# Making the data stationary for GRID SEARCH in ARIMA model

# %%
train_data_diff = training_df['Close'].diff().dropna()

# %% [markdown]
# Visually checking stationarity

# %%
window = 12
rolling_mean = train_data_diff.rolling(window=window).mean()
rolling_std = train_data_diff.rolling(window=window).std()

plt.plot(training_df, label='Original stock data')
plt.plot(rolling_mean, label='Rolling Mean')
plt.plot(rolling_std, label='Rolling Std')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# As the rolling mean and standard deviation are almost constant, let's proceed onto making the ACF and PACF plots for moving average order and autoregressive order estimation

# %%
plt.figure(figsize=(12, 6))
plot_acf(train_data_diff, lags=5)
plt.title("ACF Plot Differened Data")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plot_pacf(train_data_diff, lags=5)
plt.title("PACF Plot")
plt.show()

# %% [markdown]
# Now let's implement the grid search method for ARIMA model and I will restrict ranges to 5

# %%
def grid_search_arima(series, p_range, d_range, q_range):
    best_aic = np.inf
    best_order = None
    for p in p_range:
      for q in q_range:
        for d in d_range:
          model=ARIMA(series,order=(p,d,q)).fit()
          if model.aic < best_aic:
                best_aic = model.aic
                best_order = (p, d, q)
    return best_order


best_order = grid_search_arima(training_df, p_range=range(5), d_range=range(3), q_range=range(5))
print("Optimal ARIMA order:", best_order)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Optimal ARIMA order: (2, 1, 3)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# The output is :- "Optimal ARIMA order: (2,1,3)", which completes our ARIMA model.

# %%
final_model=ARIMA(training_df,order=(2,1,3)).fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
print(final_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Close_MSFT   No. Observations:                 1004
# Model:                 ARIMA(2, 1, 3)   Log Likelihood               -2969.433
# Date:                Tue, 14 Jan 2025   AIC                           5950.866
# Time:                        16:17:22   BIC                           5980.330
# Sample:                             0   HQIC                          5962.062
#                                - 1004
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.8183      0.040    -45.997      0.000      -1.896      -1.741
# ar.L2         -0.9321      0.037    -25.244      0.000      -1.005      -0.860
# ma.L1          1.7335      0.046     38.066      0.000       1.644       1.823
# ma.L2          0.7843      0.058     13.570      0.000       0.671       0.898
# ma.L3         -0.0543      0.031     -1.742      0.082      -0.116       0.007
# sigma2        21.8241      0.786     27.773      0.000      20.284      23.364
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                77.86
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# **Forecasting**

# %%
forecast = final_model.forecast(steps=testing_df.shape[0])
y_points=np.array(forecast)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
x_points=testing_df.index.to_numpy()

# %% [markdown]
# Plot the actual vs. predicted values for the test dataset.

# %%
plt.figure(figsize=(12, 6))
plt.plot(testing_df)
plt.plot(x_points,y_points)
plt.title("Comparison")
plt.show()

# %%
true_values=np.array(testing_df)

# %%
residual=final_model.resid
print(residual)
# Out:
# Date
# 2020-01-16    158.939163
# 2020-01-17      0.889930
# 2020-01-21     -0.481178
# 2020-01-22     -0.835051
# 2020-01-23      0.898203
#                  ...
# 2024-01-05     -0.226448
# 2024-01-08      6.421234
# 2024-01-09      2.348950
# 2024-01-10      6.213775
# 2024-01-11      3.196346
# Length: 1004, dtype: float64

# %%
plt.plot(training_df['Close'],label='Training Data')
plt.plot(x_points,y_points,color='red', label='Forecasted Data')
plt.plot(testing_df,color='orange',label='Testing Data')
plt.plot(residual,color='green',label='Model Residual')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # **LSTM Model**

# %% [markdown]
# Use a sliding window approach to convert the time series data into supervised learning format.

# %%
# working on df new
# I will write a fuction which will give two input parameters for training data
# n is the window size

#constants
window_size= 60
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001



def rolling_window(data,n):
  X=[]
  Y=[]
  size=len(data)
  for i in range(size-n):
    X.append(data['Close Normalized'][i:i+n])
    Y.append(data['Close Normalized'][i+n])
  return np.array(X),np.array(Y)

data_X_train,data_Y_train=rolling_window(training_dfnew,window_size)
data_X_test,data_Y_test=rolling_window(testing_dfnew,window_size)

data_X_train = data_X_train.reshape(data_X_train.shape[0], data_X_train.shape[1], 1)
data_X_test = data_X_test.reshape(data_X_test.shape[0], data_X_test.shape[1], 1)


model_LSTM = Sequential([
    LSTM(64, return_sequences=True, input_shape=(window_size, 1)),
    LSTM(64, return_sequences=False),
    Dense(32, activation='relu'),
    Dense(1)
])

optimizer_LSTM = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_LSTM.compile(optimizer=optimizer_LSTM, loss='mse')
history_LSTM = model_LSTM.fit(data_X_train, data_Y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(data_X_test, data_Y_test))



loss_LSTM = model_LSTM.evaluate(data_X_test, data_Y_test)
print(f"Test Loss: ",loss_LSTM)


y_pred_LSTM = model_LSTM.predict(data_X_test)
y_pred_actual_LSTM = scaler.inverse_transform(y_pred_LSTM)
y_test_actual = scaler.inverse_transform(data_Y_test.reshape(-1, 1))


plt.figure(figsize=(14, 7))
plt.plot(testing_dfnew.index[:testing_dfnew.shape[0]-window_size],y_test_actual, label='Actual Prices', color='blue')
plt.plot(testing_dfnew.index[:testing_dfnew.shape[0]-window_size],y_pred_actual_LSTM, label='Predicted Prices', color='orange')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# <ipython-input-59-8b62b4d02d4e>:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y.append(data['Close Normalized'][i+n])
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0396 - val_loss: 0.0118
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 8.4237e-04 - val_loss: 0.0015
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 8.6266e-04 - val_loss: 0.0018
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 7.9462e-04 - val_loss: 0.0014
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 7.6384e-04 - val_loss: 0.0017
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 8.0110e-04 - val_loss: 0.0013
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 7.5645e-04 - val_loss: 0.0012
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 6.7038e-04 - val_loss: 0.0012
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 6.2003e-04 - val_loss: 0.0013
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 7.1584e-04 - val_loss: 0.0017
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 7.2755e-04 - val_loss: 0.0011
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 7.7613e-04 - val_loss: 0.0018
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 6.6791e-04 - val_loss: 0.0011
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 6.0715e-04 - val_loss: 0.0012
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 6.2124e-04 - val_loss: 0.0011
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 5.3700e-04 - val_loss: 0.0016
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 6.3623e-04 - val_loss: 9.0132e-04
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 4.9128e-04 - val_loss: 8.1433e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 5.1660e-04 - val_loss: 7.6921e-04
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 4.9089e-04 - val_loss: 0.0010
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 5.4135e-04 - val_loss: 8.6726e-04
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 4.9750e-04 - val_loss: 6.7945e-04
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 4.8831e-04 - val_loss: 0.0010
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 5.4883e-04 - val_loss: 8.6335e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 4.5571e-04 - val_loss: 7.4177e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0975e-04 - val_loss: 5.8640e-04
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.6725e-04 - val_loss: 5.9193e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 4.4949e-04 - val_loss: 0.0011
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 5.0799e-04 - val_loss: 7.5540e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 4.4120e-04 - val_loss: 0.0016
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 5.4116e-04 - val_loss: 5.5317e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0780e-04 - val_loss: 5.2595e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.3102e-04 - val_loss: 5.0758e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.1869e-04 - val_loss: 6.0782e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 3.4395e-04 - val_loss: 6.7133e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 4.2730e-04 - val_loss: 6.0965e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.7248e-04 - val_loss: 4.4952e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.8590e-04 - val_loss: 5.0009e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 3.3202e-04 - val_loss: 5.0646e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 3.7200e-04 - val_loss: 4.2767e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.4159e-04 - val_loss: 4.1821e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.5219e-04 - val_loss: 4.4470e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.8589e-04 - val_loss: 5.7765e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 3.9119e-04 - val_loss: 9.6068e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 3.5893e-04 - val_loss: 4.6280e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 3.8352e-04 - val_loss: 6.5355e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 3.2808e-04 - val_loss: 4.0928e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.9929e-04 - val_loss: 4.3515e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 3.0715e-04 - val_loss: 4.0684e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.1206e-04
# Test Loss:  0.00040683720726519823
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# Model with Dropouts to prevent overfitting.

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(window_size, 1)),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
])

optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='mse')
history = model.fit(data_X_train, data_Y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(data_X_test, data_Y_test))



loss = model.evaluate(data_X_test, data_Y_test)
print(f"Test Loss: ",loss)


y_pred = model.predict(data_X_test)
y_pred_actual = scaler.inverse_transform(y_pred)


plt.figure(figsize=(14, 7))
plt.plot(testing_dfnew.index[:testing_dfnew.shape[0]-window_size],y_test_actual, label='Actual Prices', color='blue')
plt.plot(testing_dfnew.index[:testing_dfnew.shape[0]-window_size],y_pred_actual, label='Predicted Prices', color='orange')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.0586 - val_loss: 0.0262
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0012 - val_loss: 9.5121e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 9.3436e-04 - val_loss: 0.0077
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 8.8918e-04 - val_loss: 8.4879e-04
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 8.3643e-04 - val_loss: 0.0019
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 9.5707e-04 - val_loss: 8.6990e-04
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 8.6897e-04 - val_loss: 8.3079e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 8.5254e-04 - val_loss: 8.4972e-04
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 7.7140e-04 - val_loss: 7.9875e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 7.7590e-04 - val_loss: 0.0012
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 9.4437e-04 - val_loss: 9.2867e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.2679e-04 - val_loss: 7.7097e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 7.9369e-04 - val_loss: 7.0578e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 9.5266e-04 - val_loss: 7.1918e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 7.6888e-04 - val_loss: 0.0021
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 7.1157e-04 - val_loss: 9.7501e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 6.7917e-04 - val_loss: 7.7612e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 6.8693e-04 - val_loss: 8.3768e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 6.8386e-04 - val_loss: 7.5646e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.9036e-04 - val_loss: 0.0022
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0012 - val_loss: 7.0724e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 7.5239e-04 - val_loss: 0.0010
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 7.3544e-04 - val_loss: 6.6795e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.2658e-04 - val_loss: 6.5616e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 6.5965e-04 - val_loss: 6.1311e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.1164e-04 - val_loss: 6.1182e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 6.3393e-04 - val_loss: 8.4773e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 5.3939e-04 - val_loss: 5.7680e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 5.5560e-04 - val_loss: 6.1541e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.9649e-04
# Test Loss:  0.0006154135335236788
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# # **Bidirectional LSTM Implementation**

# %%
from tensorflow.keras.layers import Bidirectional
model_1= Sequential([
    Bidirectional(LSTM(64, return_sequences=True, input_shape=(window_size, 1))),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
])
optimizer_1 = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_1.compile(optimizer=optimizer_1, loss='mse')
history_1 = model_1.fit(data_X_train, data_Y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(data_X_test, data_Y_test))



loss_1 = model_1.evaluate(data_X_test, data_Y_test)
print(f"Test Loss: ",loss_1)


y_pred_1 = model_1.predict(data_X_test)
y_pred_actual_1 = scaler.inverse_transform(y_pred_1)


plt.figure(figsize=(14, 7))
plt.plot(testing_dfnew.index[:testing_dfnew.shape[0]-window_size],y_test_actual, label='Actual Prices', color='blue')
plt.plot(testing_dfnew.index[:testing_dfnew.shape[0]-window_size],y_pred_actual_1, label='Predicted Prices', color='orange')
plt.title('Stock Price Prediction Bidirectional LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 143ms/step - loss: 0.0696 - val_loss: 0.0073
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0042 - val_loss: 0.0061
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0014 - val_loss: 9.6686e-04
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0011 - val_loss: 9.1163e-04
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0011 - val_loss: 7.6853e-04
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 9.6910e-04 - val_loss: 8.3144e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 9.5753e-04 - val_loss: 7.0848e-04
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 8.5406e-04 - val_loss: 0.0014
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 8.4196e-04 - val_loss: 0.0010
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 9.5840e-04 - val_loss: 0.0031
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0011 - val_loss: 9.0731e-04
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 8.4963e-04 - val_loss: 8.4703e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 8.9423e-04 - val_loss: 7.6327e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 8.6576e-04 - val_loss: 0.0016
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 6.6367e-04 - val_loss: 0.0028
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.3696e-04 - val_loss: 0.0013
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 7.1544e-04 - val_loss: 0.0018
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 7.1230e-04 - val_loss: 6.6995e-04
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 7.5611e-04 - val_loss: 0.0019
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 7.2964e-04 - val_loss: 6.1573e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 6.5687e-04 - val_loss: 0.0013
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 6.1180e-04 - val_loss: 6.4462e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 5.7370e-04 - val_loss: 6.1030e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 6.6267e-04 - val_loss: 5.2328e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 6.1451e-04 - val_loss: 5.1472e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 5.5296e-04 - val_loss: 9.2584e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 6.5590e-04 - val_loss: 4.8884e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 5.7507e-04 - val_loss: 5.6672e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 4.9862e-04 - val_loss: 9.0735e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 5.0838e-04 - val_loss: 7.9813e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 5.3853e-04 - val_loss: 5.2571e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 5.8381e-04 - val_loss: 8.1870e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 5.0693e-04 - val_loss: 6.3881e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.5535e-04 - val_loss: 0.0012
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 5.0364e-04 - val_loss: 7.7269e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 4.3033e-04 - val_loss: 7.3442e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 5.9919e-04 - val_loss: 4.5311e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4147e-04
# Test Loss:  0.00045310528366826475
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %% [markdown]
# # **Comparison Between ARIMA and LSTM**

# %% [markdown]
# - **Mean Absolute Error (MAE)**.
# - **Root Mean Squared Error (RMSE)**.
# - **Mean Absolute Percentage Error (MAPE)**.

# %% [markdown]
# # **ARIMA**

# %%
true_values_1=np.array(testing_df)
mae_ARIMA = np.mean(np.abs(true_values_1 - y_points))
mse_ARIMA = np.mean((true_values_1 - y_points) ** 2)
rmse_ARIMA = np.sqrt(mse_ARIMA)
print("ARIMA:-")
print(f"MAE: {mae_ARIMA}")
print(f"MSE: {mse_ARIMA}")
print(f"RMSE: {rmse_ARIMA}")
# Out:
# ARIMA:-
# MAE: 38.339706819098566
# MSE: 1725.0135641162803
# RMSE: 41.53328260704035

# %% [markdown]
# # **LSTM**

# %%
mae_LSTM_o = np.mean(np.abs(y_test_actual - y_pred_actual_LSTM))
mse_LSTM_o = np.mean((y_test_actual -y_pred_actual_LSTM) ** 2)
rmse_LSTM_o = np.sqrt(mse_LSTM_o)
print("LSTM:-")
print(f"MAE: {mae_LSTM_o}")
print(f"MSE: {mse_LSTM_o}")
print(f"RMSE: {rmse_LSTM_o}")
# Out:
# LSTM:-
# MAE: 5.377249081929524
# MSE: 45.90444108361654
# RMSE: 6.775281623933911

# %%
mae_LSTM = np.mean(np.abs(y_test_actual - y_pred_actual))
mse_LSTM = np.mean((y_test_actual -y_pred_actual) ** 2)
rmse_LSTM = np.sqrt(mse_LSTM)
print("LSTM_Dropouts:-")
print(f"MAE: {mae_LSTM}")
print(f"MSE: {mse_LSTM}")
print(f"RMSE: {rmse_LSTM}")
# Out:
# LSTM_Dropouts:-
# MAE: 6.677230040232343
# MSE: 69.43858925722218
# RMSE: 8.33298201469451

# %%
mae_LSTM_1 = np.mean(np.abs(y_test_actual - y_pred_actual_1))
mse_LSTM_1 = np.mean((y_test_actual -y_pred_actual_1) ** 2)
rmse_LSTM_1 = np.sqrt(mse_LSTM_1)
print("LSTM_Bidirectional:-")
print(f"MAE: {mae_LSTM_1}")
print(f"MSE: {mse_LSTM_1}")
print(f"RMSE: {rmse_LSTM_1}")
# Out:
# LSTM_Bidirectional:-
# MAE: 5.647843360900882
# MSE: 51.12499519470541
# RMSE: 7.150174487011167

# %% [markdown]
# - Write an analysis of  the **strengths and weaknesses** of both models in terms of:
#     - Handling seasonality and trends.
#     - Ability to capture non-linear patterns.
#     - Computational complexity.

# %% [markdown]
# I think the ARIMA model is well in capturing the mean of the data, it predicts the trend but can't predict the flactuations in data. The LSTM model captures both the flactuations and trends in data quite well and has the ability to caputre non-linear pattern.

# %% [markdown]
# LSTM is more computationally complex, also I think it could be made more complex by adding a grid search for constants window_size, BATCH_SIZE ,EPOCHS, LEARNING_RATE and then minimizing the loss.

# %% [markdown]
# # **Learning Curve for LSTM (training vs. validation loss).**

# %% [markdown]
# Plotting how the model evolves, by keeping the track of losses

# %%
train_loss = history_1.history['loss']
val_loss = history_1.history['val_loss']


plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve: Training vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
